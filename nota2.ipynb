# %% [markdown]
# <a href="https://colab.research.google.com/github/GeraHn10/NotesTeoriaCompu/blob/master/nota2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Automatas

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
G.add_nodes_from(["q0","q1","q2"])
G.add_edges_from([("q0","q0",{'char': 'a'}),("q0", "q1",{'element': '0'}),
                  ("q1", "q1",{'element':'0'}),("q1", "q2",{'element':'1'}),
                  ("q1", "q2",{'element':'0'}) ])
print("Q: ")
print(G.nodes())
print("Edges of graph: ")
print(G.edges())
nx.draw(G,with_labels=True)
plt.show()
# Out:
# Q:
# ['q0', 'q1', 'q2']
# Edges of graph:
# [('q0', 'q0'), ('q0', 'q1'), ('q1', 'q1'), ('q1', 'q2')]

# %% [markdown]
# Ejemplo 2 automatas

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
G.add_nodes_from(["q0","q1","q2","q3"])
G.add_edges_from([("q0","q0",{'char': 'a'}),("q0", "q1",{'element': '0'}),
                  ("q1", "q0",{'element':'0'}),("q1", "q2",{'element':'1'}),
                  ("q0", "q2",{'element':'0'}) ,("q3", "q3",{'element':'0'}) ,("q2", "q3",{'element':'0'})])
print("Q: ")
print(G.nodes())
print("Edges of graph: ")
print(G.edges())
nx.draw(G,with_labels=True)
plt.show()
# Out:
# Q:
# ['q0', 'q1', 'q2', 'q3']
# Edges of graph:
# [('q0', 'q0'), ('q0', 'q1'), ('q0', 'q2'), ('q1', 'q2'), ('q2', 'q3'), ('q3', 'q3')]

# %% [markdown]
# Dinamismo en Grafos

# %%
import networkx as nx
import random
import matplotlib.pyplot as plt

# grafo de n nodos donde la probabilidad de que un eje exista es de p
n = 5
G = nx.complete_graph(n)
for (u, v, w) in G.edges(data=True):
    w['weight'] = random.randint(0, 10)

edge_labels = nx.get_edge_attributes(G, 'weight')
label = nx.nodes(G)
nx.draw_shell(G, with_labels=True, edge_labels=edge_labels)
plt.show()
